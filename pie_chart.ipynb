# %% [markdown]
# <a href="https://colab.research.google.com/github/mfernandezzz/matplotlibCS/blob/main/pie_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt

# %%
plt.style.use('ggplot')

plt.figure(figsize=(14, 7))

slices = [59219, 55466, 47544, 36443, 35917]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']
colors = ['#008fd5', '#fc4f30', '#e5ae37', '#6d904f', 'purple']
explode = [0, 0, 0, 0.1, 0]

plt.pie(slices, labels=labels, colors=colors, explode=explode, shadow=True,
        startangle=90, autopct='%1.1f%%', wedgeprops={'edgecolor': 'black'})

plt.title("Programming Languages Popularity")
plt.tight_layout()
plt.show()
