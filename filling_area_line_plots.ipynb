# %% [markdown]
# <a href="https://colab.research.google.com/github/mfernandezzz/matplotlibCS/blob/main/filling_area_line_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('/content/data2.csv')
data.head()
# Out:
#    Age  All_Devs  Python  JavaScript
# 0   18     17784   20046       16446
# 1   19     16500   17100       16791
# 2   20     18012   20000       18942
# 3   21     20628   24744       21780
# 4   22     25206   30500       25704

# %%
data.describe()
# Out:
#              Age       All_Devs         Python     JavaScript
# count  38.000000      38.000000      38.000000      38.000000
# mean   36.500000   69257.078947   74464.289474   69707.921053
# std    11.113055   28739.996679   30851.867158   28899.282262
# min    18.000000   16500.000000   17100.000000   16446.000000
# 25%    27.250000   47394.000000   49157.000000   47440.500000
# 50%    36.500000   77616.000000   84016.000000   78754.000000
# 75%    45.750000   91653.250000   99810.000000   91660.000000
# max    55.000000  108923.000000  122870.000000  108000.000000

# %%
#from numpy import median
#overall_median = median(data['All_Devs'])
overall_median = data['All_Devs'].median()
overall_median
# Out:
# 77616.0

# %%
from numpy import median
plt.style.use('fivethirtyeight')

plt.figure(figsize=(14, 7))

ages = data['Age']
dev_salaries = data['All_Devs']
py_salaries = data['Python']
js_salaries = data['JavaScript']

plt.plot(ages, py_salaries, label='Python')
#plt.plot(ages, js_salaries, label='JavaScript')
plt.plot(ages, dev_salaries, color='#444444', linestyle='--', label='All Devs')

overall_median = median(dev_salaries)
# plt.axhline(overall_median, color='#444444', label='Overall Median')

plt.fill_between(ages, py_salaries, dev_salaries,
                 where=(py_salaries > dev_salaries), interpolate=True,
                 alpha=0.25, label='Above Avg')

plt.fill_between(ages, py_salaries, dev_salaries,
                 where=(py_salaries <= dev_salaries), interpolate=True,
                 color='red', alpha=0.25, label='Below Avg')

plt.legend()

plt.title('Median Salary (USD) by Age')
plt.xlabel('Ages')
plt.ylabel('Median Salary (USD)')

plt.tight_layout()

plt.show()
